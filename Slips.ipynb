# %% [markdown]
# # Set 1 - complete

# %%
#grayscale 
# %matplotlib inline 
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import cv2 
image = cv2.imread('/content/s1.png')
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=368x268 at 0x7FBFEC4A0940>

# %%
#hsv image
import cv2 
image = cv2.imread('s1.png')
hsv = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
cv2_imshow(hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=368x268 at 0x7FBFDEDEFF70>

# %%
#bgrimage
import cv2 
image = cv2.imread('s1.png')
bgr = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
cv2_imshow(bgr)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=368x268 at 0x7F1E6E915310>

# %%
#rgb image
import cv2 
image = cv2.imread('s1.png')
rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB )
cv2_imshow(rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=368x268 at 0x7FBFDEEE2A30>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt 
from random import randrange
img = cv2.imread('s1.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
cv2_imshow(gray)
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(rgb)
bgr = cv2.cvtColor(rgb, cv2.COLOR_RGB2BGR)
cv2_imshow(bgr)
red = img[:,:,0]
cv2_imshow(red)
# Out:
# <PIL.Image.Image image mode=RGB size=368x268 at 0x7FBFEED0FAC0>
# <PIL.Image.Image image mode=L size=368x268 at 0x7FBFEECFE8E0>
# <PIL.Image.Image image mode=RGB size=368x268 at 0x7FBFEED0FA90>
# <PIL.Image.Image image mode=RGB size=368x268 at 0x7FBFEECFE8E0>
# <PIL.Image.Image image mode=L size=368x268 at 0x7FBFEECFE8E0>

# %%
img = cv2.imread('/content/s1i2.png', cv2.IMREAD_COLOR)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_blurred = cv2.blur(gray, (3,3))
detected_circles = cv2.HoughCircles(gray_blurred,
                                    cv2.HOUGH_GRADIENT, 1, 30, param1 = 80,
                                    param2 = 40, minRadius = 240, maxRadius = 240)
if detected_circles is not None:
  detected_circles = np.uint16(np.around(detected_circles))
  for pt in detected_circles[0, :]:
    a, b, r = pt[0], pt[1], pt[2]
    cv2.circle(img, (a,b), r, (0, 255,0), 2)
    cv2.circle(img, (a,b), 1, (0,0, 255),3)

cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=483x317 at 0x7FBFDEDEFE20>
# -1

# %% [markdown]
# # Set 2

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
import numpy as np

img = cv.imread('/content/s2i2.png')
cv2_imshow(img)

blur = cv.blur(img,(5,5))# Averaging
cv2_imshow(blur)

blur0=cv.medianBlur(img,5) # Median blurring
cv2_imshow(blur0)

blur1= cv.GaussianBlur(img,(5,5),0)# Gaussian Blurring
cv2_imshow(blur1)

blur2= cv.bilateralFilter(img,9,75,75) # Bilateral Filtering
cv2_imshow(blur2)
# Out:
# <PIL.Image.Image image mode=RGB size=500x310 at 0x7FBFDEEE6490>
# <PIL.Image.Image image mode=RGB size=500x310 at 0x7FBFF0BFAF70>
# <PIL.Image.Image image mode=RGB size=500x310 at 0x7FBFEED0F9A0>
# <PIL.Image.Image image mode=RGB size=500x310 at 0x7FBFF0BFAF70>
# <PIL.Image.Image image mode=RGB size=500x310 at 0x7FBFEED0F9A0>

# %% [markdown]
# # Set 3 - Complete

# %%
#set 3 blob
import cv2
import numpy as np
im= cv2.imread('/content/s3i1.png')
gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
#cv2_imshow(im)
params=cv2.SimpleBlobDetector_Params()
detector = cv2.SimpleBlobDetector_create(params)
keypoints= detector.detect(gray)
im_with_keypoints=cv2.drawKeypoints(gray,keypoints,np.array([]),(0,0,255),cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv2_imshow(im_with_keypoints)
#cv2.imshow("test", im_with_keypoints)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=602x469 at 0x7F1E5C149B80>

# %%
#set 3 edge detection i have used canny 


#canny edge detection 

import numpy as np
import cv2
#from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
img = cv2.imread('/content/s3i2.png')
#cv2_imshow(img)
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#blur the image for better edge detection
img_blur= cv2.GaussianBlur(img_gray,(3,3),0)
#sobel edge detection
sobelx= cv2.Sobel(src=img_blur,ddepth=cv2.CV_64F,dx=1,dy=0,ksize=5)
sobely= cv2.Sobel(src=img_blur,ddepth=cv2.CV_64F,dx=0,dy=1,ksize=5)
sobelxy= cv2.Sobel(src=img_blur,ddepth=cv2.CV_64F,dx=1,dy=1,ksize=5)
plt.subplot(1,3,1),plt.imshow(sobelx,cmap='gray')
plt.title('Sobel X axis'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,2),plt.imshow(sobely,cmap='gray')
plt.title('Sobel Y axis'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,3),plt.imshow(sobely,cmap='gray')
plt.title('Sobel XY axis'),plt.xticks([]),plt.yticks([])
plt.show()
#canny
edges = cv2.Canny(image=img_blur,threshold1=50,threshold2=60)
cv2_imshow(edges)
#cv2.imshow("test", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=399x400 at 0x7F1E5BC15400>

# %% [markdown]
# # Set 4 - complete

# %%
# set 4 threhodling 

import cv2
#from google.colab.patches import cv2_imshow
img = cv2.imread('/content/s4i1.png')
retval,threshold = cv2.threshold(img,62,255,cv2.THRESH_BINARY_INV)
cv2_imshow(img)
cv2_imshow(threshold)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=507x400 at 0x7FBFEECFE9D0>
# <PIL.Image.Image image mode=RGB size=507x400 at 0x7FBFDEEE66D0>

# %%
# set 4 

#hough line detection
import cv2
import numpy as np
#from google.colab.patches import cv2_imshow
img= cv2.imread('/content/s4i2.png',cv2.IMREAD_COLOR)
#cv2_imshow(img)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#find the edges in the image using canny detector
edges=cv2.Canny(gray,550,550)
#detect points that form a line
lines= cv2.HoughLinesP(edges,1,np.pi/180,1,minLineLength=1,maxLineGap=1)
#draw lines on image
for line in lines:
  x1,y1,x2,y2 = line[0]
  cv2.line(img,(x1,y1),(x2,y2),(255,0,0),3)

cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=602x400 at 0x7FBFDCB6C820>

# %% [markdown]
# # Set 5 - complete

# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
image = cv2.imread('s5i1.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
 
blur = cv2.GaussianBlur(gray, (11, 11), 0)
canny = cv2.Canny(blur, 30, 150, 3)
dilated = cv2.dilate(canny, (1, 1), iterations=0)
 
(cnt, hierarchy) = cv2.findContours(
    dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0, 255, 0), 2)
 
 
print("shapes in the image : ", len(cnt))
# Out:
# shapes in the image :  17

# %%
image = cv2.imread('s5i1.png')
cv2_imshow(image)
#Changing the color -space
imgray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#Find edges
edges = cv2.Canny(imgray, 10, 80)
#Find Contours
contours, hierarchy = cv2.findContours(edges, cv2.RETR_EXTERNAL, 
cv2.CHAIN_APPROX_NONE)
#Number of contours
print("Number of contours is : " + str(len(contours)))
#Draw yellow border around two contours
cv2.drawContours(image, contours, -1, (0, 230, 255), 6)
#Show the image with contours
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7FBFDEDEF850>
# Number of contours is : 1
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7FBFDEDEF130>

# %%
set5a=cv2.imread('s5i1.png')
cv2_imshow(set5a)
set5a_gray=cv2.cvtColor(set5a,cv2.COLOR_BGR2GRAY)
edge=cv2.Canny(set5a_gray,10,95)


contours,hierarchy = cv2.findContours(edge,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
print("Number of shapes in iamge are",len(contours))

cv2.drawContours(set5a, contours, -1, (0, 230, 255), 6)
#Show the image with contours
cv2_imshow(set5a)
# Out:
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7FBFDEEE60A0>
# Number of shapes in iamge are 1
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7FBFDEEE60A0>

# %%
# %matplotlib inline
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

img2=cv2.imread('/content/s5i2.png',0)
cv2_imshow(img2)
equal=cv2.equalizeHist(img2)
cv2_imshow(equal)
# Out:
# <PIL.Image.Image image mode=L size=450x730 at 0x7FBFDEEE6640>
# <PIL.Image.Image image mode=L size=450x730 at 0x7FBFDEEE6640>

# %% [markdown]
# # Set 6 - complete

# %%
#set 6 blob
import cv2
import numpy as np
im= cv2.imread('/content/s6i1.png')
gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
#cv2_imshow(im)
params=cv2.SimpleBlobDetector_Params()
detector = cv2.SimpleBlobDetector_create(params)
keypoints= detector.detect(gray)
im_with_keypoints=cv2.drawKeypoints(gray,keypoints,np.array([]),(0,0,255),cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#cv2_imshow(im_with_keypoints)
cv2_imshow(im_with_keypoints)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FBFEC4A0970>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load Image
img=cv2.imread('s6i1.png')
cv2_imshow(img)
image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# set filtering by parameters
# initialize parameter setting using cv2.SimpleBlobDetector

params=cv2.SimpleBlobDetector_Params()

# area filter
params.filterByArea=True
params.minArea=100

#circularity filter
params.filterByCircularity=True
params.minCircularity=0.8
#convexity filtering parameters
params.filterByConvexity=True
params.minConvexity=0.2

#set inertia filtering parameters
params.filterByInertia=True
params.minInertiaRatio=0.01

#create a detector with parameters
detector=cv2.SimpleBlobDetector_create(params)

#detect blobs

keypoints=detector.detect(image)

# draw blobs on our image as circles

blank=np.zeros((1,1))
blobs=cv2.drawKeypoints(image,keypoints,blank,(0,0,255),cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

number_of_blob=len(keypoints)
text="no of blobs:" + str(len(keypoints))
cv2.putText(blobs,text,(20,550),cv2.FONT_HERSHEY_SIMPLEX,1,(0,100,255),2)

# show blobs 

cv2_imshow(blobs)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FBFDEEE2A30>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FBFDEEF55B0>

# %%
img=cv2.imread("s6i2.png")


#Rotate
import cv2
import numpy as np
img_rotate=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(img_rotate)


#Scaling
shrink_image = cv2.resize(img, (0, 0), fx = 0.1, fy = 0.1)
cv2_imshow(shrink_image)
# Out:
# <PIL.Image.Image image mode=RGB size=92x85 at 0x7FBFEC4A0CA0>
# <PIL.Image.Image image mode=RGB size=8x9 at 0x7FBFEC4A0CA0>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
image=cv2.imread('s6i3.png')
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)


faceCascade=cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')

# detect faces in image

faces=faceCascade.detectMultiScale(gray,
                                   scaleFactor=1.05,
                                   minNeighbors=5,
                                   flags=cv2.CASCADE_SCALE_IMAGE)

print (" Found {0} faces!".format(len(faces)))
for(x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),0)

cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7FBFDEEE2CD0>
#  Found 4 faces!
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FBFDEDEFEB0>
# -1
